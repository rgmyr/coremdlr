# %% [markdown]
# ### Purpose
#
# Test the WaveNet network on `pseudoGR` features. Demonstrate the difference between `categorical` loss, `ordinal` loss, and a combination.

# %%
import numpy as np
from sklearn.metrics import confusion_matrix

from coremdlr.viz import model_plots
from coremdlr.models import NetworkModel
from coremdlr.datasets import DepthSequenceGenerator, FaciesDataset

import os

os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="1"

import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
well_names = ["205-21b-3", "204-20-6a", "204-24a-6", "204-20-1Z", "204-19-6", "204-20-1"]
#well_names = [ "204-19-7", "204-20-1","204-20-1Z","204-20-2","204-20-3", "205-21b-3", "204-24a-7" ]

loss_options = ('categorical_crossentropy',
                'ordinal_squared_error',
                {'categorical_crossentropy': 0.2,
                 'ordinal_squared_error': 0.8})

wavenet_model_args = {
    'feature' : 'pseudoGR',
    'network' : 'wavenet',
    'sequence_size' : 128,
    'network_args' : {
        'num_blocks' : 20,
        'block_filters' : 128,
        'residual_filters' : 64,
        'output_resolution' : 32,
        'dropout_rate' : 0.5,
    },
    'optimizer_args' : {
        'optimizer' : 'Adam'
    }
}

fit_args = {
    'batch_size' : 16,
    'epochs' : 15,
    'class_weighted': True
}

# %%
np.type(well_names)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-e8a9fa450eca> in <module>()
# ----> 1 np.type(well_names)
#
# AttributeError: module 'numpy' has no attribute 'type'

# %%
for test_well in well_names:
    
    print(f'\n\nTESTING WITH TEST WELL: {test_well}\n\n')
    
    fdset = FaciesDataset([name for name in well_names if name != test_well],
                    test_wells=[test_well],
                    features=["pseudoGR"],
                    label_resolution=32, 
                    pseudoGR_args={'scale_mode' : 'robust'})

    fdset.load_or_generate_data()
    
    for loss in loss_options:
        
        print(f'\nMODELING WITH LOSS: {loss}\n')
        
        model_args = {**wavenet_model_args, **{'loss': loss}}
        
        wavenet_model = NetworkModel(fdset, model_args=wavenet_model_args)
    
        wavenet_model.fit(fdset, **fit_args)
        
        y_pred = wavenet_model.predict(fdset.X_test)

        cm = confusion_matrix(fdset.y_test, y_pred)
        
        fig, ax = plt.subplots(ncols=2, sharey=True, figsize=(20,10))
        fig.suptitle(f'{test_well}: {loss}')

        model_plots.confusion_matrix_plot(cm, fdset.classes, ax=ax[0])
        model_plots.confusion_matrix_plot(cm, fdset.classes, ax=ax[1], normalize=True)
        
        plt.show()
# Out:
# TESTING WITH TEST WELL: 205-21b-3
#
#
# Loading Well:  204-20-6a  from  /home/administrator/Dropbox/core_data/facies/train_data
# /home/administrator/code/python/coremdlr/coremdlr/datasets/utils.py:79: RuntimeWarning: Mean of empty slice
#   output_features.append(np.nanmean(img, axis=1))
# /home/administrator/code/python/coremdlr/coremdlr/datasets/utils.py:83: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   output_features.append(np.nanvar(img, axis=1))
# Extracted pGR features:  ['Umean', 'Rmean', 'Gmean', 'Bmean', 'Uvar', 'Rvar', 'Gvar', 'Bvar']
# Feature shapes:  [('depth', (3542,)), ('top', (3542,)), ('base', (3542,)), ('pseudoGR', (3542, 32, 8))]
# Loading Well:  204-24a-6  from  /home/administrator/Dropbox/core_data/facies/train_data
# Extracted pGR features:  ['Umean', 'Rmean', 'Gmean', 'Bmean', 'Uvar', 'Rvar', 'Gvar', 'Bvar']
# Feature shapes:  [('depth', (13006,)), ('top', (13006,)), ('base', (13006,)), ('pseudoGR', (13006, 32, 8))]
# Loading Well:  204-20-1Z  from  /home/administrator/Dropbox/core_data/facies/train_data
# Extracted pGR features:  ['Umean', 'Rmean', 'Gmean', 'Bmean', 'Uvar', 'Rvar', 'Gvar', 'Bvar']
# Feature shapes:  [('depth', (1917,)), ('top', (1917,)), ('base', (1917,)), ('pseudoGR', (1917, 32, 8))]
# Loading Well:  204-19-6  from  /home/administrator/Dropbox/core_data/facies/train_data
# Extracted pGR features:  ['Umean', 'Rmean', 'Gmean', 'Bmean', 'Uvar', 'Rvar', 'Gvar', 'Bvar']
# Feature shapes:  [('depth', (1884,)), ('top', (1884,)), ('base', (1884,)), ('pseudoGR', (1884, 32, 8))]
# Loading Well:  204-20-1  from  /home/administrator/Dropbox/core_data/facies/train_data
# Extracted pGR features:  ['Umean', 'Rmean', 'Gmean', 'Bmean', 'Uvar', 'Rvar', 'Gvar', 'Bvar']
# Feature shapes:  [('depth', (11210,)), ('top', (11210,)), ('base', (11210,)), ('pseudoGR', (11210, 32, 8))]
# Loading Well:  205-21b-3  from  /home/administrator/Dropbox/core_data/facies/train_data
# /home/administrator/code/python/coremdlr/coremdlr/datasets/utils.py:79: RuntimeWarning: Mean of empty slice
#   output_features.append(np.nanmean(img, axis=1))
# /home/administrator/code/python/coremdlr/coremdlr/datasets/utils.py:83: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   output_features.append(np.nanvar(img, axis=1))
# Extracted pGR features:  ['Umean', 'Rmean', 'Gmean', 'Bmean', 'Uvar', 'Rvar', 'Gvar', 'Bvar']
# Feature shapes:  [('depth', (3842,)), ('top', (3842,)), ('base', (3842,)), ('pseudoGR', (3842, 32, 8))]
#
# MODELING WITH LOSS: categorical_crossentropy
#
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 4096, 8)      0
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 4096, 64)     3648        input_1[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 4096, 128)    24704       conv1d[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 4096, 128)    24704       conv1d[0][0]
# __________________________________________________________________________________________________
# multiply (Multiply)             (None, 4096, 128)    0           conv1d_1[0][0]
#                                                                  conv1d_2[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 4096, 64)     8256        multiply[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 4096, 64)     0           conv1d_3[0][0]
#                                                                  conv1d[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 4096, 128)    24704       add[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 4096, 128)    24704       add[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 4096, 128)    0           conv1d_4[0][0]
#                                                                  conv1d_5[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 4096, 64)     8256        multiply_1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 4096, 64)     0           conv1d_6[0][0]
#                                                                  add[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 4096, 128)    24704       add_1[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 4096, 128)    24704       add_1[0][0]
# __________________________________________________________________________________________________
# multiply_2 (Multiply)           (None, 4096, 128)    0           conv1d_7[0][0]
#                                                                  conv1d_8[0][0]
# __________________________________________________________________________________________________
# conv1d_9 (Conv1D)               (None, 4096, 64)     8256        multiply_2[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 4096, 64)     0           conv1d_9[0][0]
#                                                                  add_1[0][0]
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, 4096, 128)    24704       add_2[0][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, 4096, 128)    24704       add_2[0][0]
# __________________________________________________________________________________________________
# multiply_3 (Multiply)           (None, 4096, 128)    0           conv1d_10[0][0]
#                                                                  conv1d_11[0][0]
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, 4096, 64)     8256        multiply_3[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 4096, 64)     0           conv1d_12[0][0]
#                                                                  add_2[0][0]
# __________________________________________________________________________________________________
# conv1d_13 (Conv1D)              (None, 4096, 128)    24704       add_3[0][0]
# __________________________________________________________________________________________________
# conv1d_14 (Conv1D)              (None, 4096, 128)    24704       add_3[0][0]
# __________________________________________________________________________________________________
# multiply_4 (Multiply)           (None, 4096, 128)    0           conv1d_13[0][0]
#                                                                  conv1d_14[0][0]
# __________________________________________________________________________________________________
# conv1d_15 (Conv1D)              (None, 4096, 64)     8256        multiply_4[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 4096, 64)     0           conv1d_15[0][0]
#                                                                  add_3[0][0]
# __________________________________________________________________________________________________
# conv1d_16 (Conv1D)              (None, 4096, 128)    24704       add_4[0][0]
# __________________________________________________________________________________________________
# conv1d_17 (Conv1D)              (None, 4096, 128)    24704       add_4[0][0]
# __________________________________________________________________________________________________
# multiply_5 (Multiply)           (None, 4096, 128)    0           conv1d_16[0][0]
#                                                                  conv1d_17[0][0]
# __________________________________________________________________________________________________
# conv1d_18 (Conv1D)              (None, 4096, 64)     8256        multiply_5[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 4096, 64)     0           conv1d_18[0][0]
#                                                                  add_4[0][0]
# __________________________________________________________________________________________________
# conv1d_19 (Conv1D)              (None, 4096, 128)    24704       add_5[0][0]
# __________________________________________________________________________________________________
# conv1d_20 (Conv1D)              (None, 4096, 128)    24704       add_5[0][0]
# __________________________________________________________________________________________________
# multiply_6 (Multiply)           (None, 4096, 128)    0           conv1d_19[0][0]
#                                                                  conv1d_20[0][0]
# __________________________________________________________________________________________________
# conv1d_21 (Conv1D)              (None, 4096, 64)     8256        multiply_6[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 4096, 64)     0           conv1d_21[0][0]
#                                                                  add_5[0][0]
# __________________________________________________________________________________________________
# conv1d_22 (Conv1D)              (None, 4096, 128)    24704       add_6[0][0]
# __________________________________________________________________________________________________
# conv1d_23 (Conv1D)              (None, 4096, 128)    24704       add_6[0][0]
# __________________________________________________________________________________________________
# multiply_7 (Multiply)           (None, 4096, 128)    0           conv1d_22[0][0]
#                                                                  conv1d_23[0][0]
# __________________________________________________________________________________________________
# conv1d_24 (Conv1D)              (None, 4096, 64)     8256        multiply_7[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 4096, 64)     0           conv1d_24[0][0]
#                                                                  add_6[0][0]
# __________________________________________________________________________________________________
# conv1d_25 (Conv1D)              (None, 4096, 128)    24704       add_7[0][0]
# __________________________________________________________________________________________________
# conv1d_26 (Conv1D)              (None, 4096, 128)    24704       add_7[0][0]
# __________________________________________________________________________________________________
# multiply_8 (Multiply)           (None, 4096, 128)    0           conv1d_25[0][0]
#                                                                  conv1d_26[0][0]
# __________________________________________________________________________________________________
# conv1d_27 (Conv1D)              (None, 4096, 64)     8256        multiply_8[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 4096, 64)     0           conv1d_27[0][0]
#                                                                  add_7[0][0]
# __________________________________________________________________________________________________
# conv1d_28 (Conv1D)              (None, 4096, 128)    24704       add_8[0][0]
# __________________________________________________________________________________________________
# conv1d_29 (Conv1D)              (None, 4096, 128)    24704       add_8[0][0]
# __________________________________________________________________________________________________
# multiply_9 (Multiply)           (None, 4096, 128)    0           conv1d_28[0][0]
#                                                                  conv1d_29[0][0]
# __________________________________________________________________________________________________
# conv1d_30 (Conv1D)              (None, 4096, 64)     8256        multiply_9[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 4096, 64)     0           conv1d_30[0][0]
#                                                                  add_8[0][0]
# __________________________________________________________________________________________________
# conv1d_31 (Conv1D)              (None, 4096, 128)    24704       add_9[0][0]
# __________________________________________________________________________________________________
# conv1d_32 (Conv1D)              (None, 4096, 128)    24704       add_9[0][0]
# __________________________________________________________________________________________________
# multiply_10 (Multiply)          (None, 4096, 128)    0           conv1d_31[0][0]
#                                                                  conv1d_32[0][0]
# __________________________________________________________________________________________________
# conv1d_33 (Conv1D)              (None, 4096, 64)     8256        multiply_10[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 4096, 64)     0           conv1d_33[0][0]
#                                                                  add_9[0][0]
# __________________________________________________________________________________________________
# conv1d_34 (Conv1D)              (None, 4096, 128)    24704       add_10[0][0]
# __________________________________________________________________________________________________
# conv1d_35 (Conv1D)              (None, 4096, 128)    24704       add_10[0][0]
# __________________________________________________________________________________________________
# multiply_11 (Multiply)          (None, 4096, 128)    0           conv1d_34[0][0]
#                                                                  conv1d_35[0][0]
# __________________________________________________________________________________________________
# conv1d_36 (Conv1D)              (None, 4096, 64)     8256        multiply_11[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 4096, 64)     0           conv1d_36[0][0]
#                                                                  add_10[0][0]
# __________________________________________________________________________________________________
# conv1d_37 (Conv1D)              (None, 4096, 128)    24704       add_11[0][0]
# __________________________________________________________________________________________________
# conv1d_38 (Conv1D)              (None, 4096, 128)    24704       add_11[0][0]
# __________________________________________________________________________________________________
# multiply_12 (Multiply)          (None, 4096, 128)    0           conv1d_37[0][0]
#                                                                  conv1d_38[0][0]
# __________________________________________________________________________________________________
# conv1d_39 (Conv1D)              (None, 4096, 64)     8256        multiply_12[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 4096, 64)     0           conv1d_39[0][0]
#                                                                  add_11[0][0]
# __________________________________________________________________________________________________
# conv1d_40 (Conv1D)              (None, 4096, 128)    24704       add_12[0][0]
# __________________________________________________________________________________________________
# conv1d_41 (Conv1D)              (None, 4096, 128)    24704       add_12[0][0]
# __________________________________________________________________________________________________
# multiply_13 (Multiply)          (None, 4096, 128)    0           conv1d_40[0][0]
#                                                                  conv1d_41[0][0]
# __________________________________________________________________________________________________
# conv1d_42 (Conv1D)              (None, 4096, 64)     8256        multiply_13[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 4096, 64)     0           conv1d_42[0][0]
#                                                                  add_12[0][0]
# __________________________________________________________________________________________________
# conv1d_43 (Conv1D)              (None, 4096, 128)    24704       add_13[0][0]
# __________________________________________________________________________________________________
# conv1d_44 (Conv1D)              (None, 4096, 128)    24704       add_13[0][0]
# __________________________________________________________________________________________________
# multiply_14 (Multiply)          (None, 4096, 128)    0           conv1d_43[0][0]
#                                                                  conv1d_44[0][0]
# __________________________________________________________________________________________________
# conv1d_45 (Conv1D)              (None, 4096, 64)     8256        multiply_14[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 4096, 64)     0           conv1d_45[0][0]
#                                                                  add_13[0][0]
# __________________________________________________________________________________________________
# conv1d_46 (Conv1D)              (None, 4096, 128)    24704       add_14[0][0]
# __________________________________________________________________________________________________
# conv1d_47 (Conv1D)              (None, 4096, 128)    24704       add_14[0][0]
# __________________________________________________________________________________________________
# multiply_15 (Multiply)          (None, 4096, 128)    0           conv1d_46[0][0]
#                                                                  conv1d_47[0][0]
# __________________________________________________________________________________________________
# conv1d_48 (Conv1D)              (None, 4096, 64)     8256        multiply_15[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 4096, 64)     0           conv1d_48[0][0]
#                                                                  add_14[0][0]
# __________________________________________________________________________________________________
# conv1d_49 (Conv1D)              (None, 4096, 128)    24704       add_15[0][0]
# __________________________________________________________________________________________________
# conv1d_50 (Conv1D)              (None, 4096, 128)    24704       add_15[0][0]
# __________________________________________________________________________________________________
# multiply_16 (Multiply)          (None, 4096, 128)    0           conv1d_49[0][0]
#                                                                  conv1d_50[0][0]
# __________________________________________________________________________________________________
# conv1d_51 (Conv1D)              (None, 4096, 64)     8256        multiply_16[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 4096, 64)     0           conv1d_51[0][0]
#                                                                  add_15[0][0]
# __________________________________________________________________________________________________
# conv1d_52 (Conv1D)              (None, 4096, 128)    24704       add_16[0][0]
# __________________________________________________________________________________________________
# conv1d_53 (Conv1D)              (None, 4096, 128)    24704       add_16[0][0]
# __________________________________________________________________________________________________
# multiply_17 (Multiply)          (None, 4096, 128)    0           conv1d_52[0][0]
#                                                                  conv1d_53[0][0]
# __________________________________________________________________________________________________
# conv1d_54 (Conv1D)              (None, 4096, 64)     8256        multiply_17[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 4096, 64)     0           conv1d_54[0][0]
#                                                                  add_16[0][0]
# __________________________________________________________________________________________________
# conv1d_55 (Conv1D)              (None, 4096, 128)    24704       add_17[0][0]
# __________________________________________________________________________________________________
# conv1d_56 (Conv1D)              (None, 4096, 128)    24704       add_17[0][0]
# __________________________________________________________________________________________________
# multiply_18 (Multiply)          (None, 4096, 128)    0           conv1d_55[0][0]
#                                                                  conv1d_56[0][0]
# __________________________________________________________________________________________________
# conv1d_57 (Conv1D)              (None, 4096, 64)     8256        multiply_18[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, 4096, 64)     0           conv1d_57[0][0]
#                                                                  add_17[0][0]
# __________________________________________________________________________________________________
# conv1d_58 (Conv1D)              (None, 4096, 128)    24704       add_18[0][0]
# __________________________________________________________________________________________________
# conv1d_59 (Conv1D)              (None, 4096, 128)    24704       add_18[0][0]
# __________________________________________________________________________________________________
# multiply_19 (Multiply)          (None, 4096, 128)    0           conv1d_58[0][0]
#                                                                  conv1d_59[0][0]
# __________________________________________________________________________________________________
# conv1d_60 (Conv1D)              (None, 4096, 64)     8256        multiply_19[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, 4096, 64)     0           conv1d_60[0][0]
#                                                                  add_18[0][0]
# __________________________________________________________________________________________________
# conv1d_61 (Conv1D)              (None, 4096, 128)    24704       add_19[0][0]
# __________________________________________________________________________________________________
# conv1d_62 (Conv1D)              (None, 4096, 128)    24704       add_19[0][0]
# __________________________________________________________________________________________________
# multiply_20 (Multiply)          (None, 4096, 128)    0           conv1d_61[0][0]
#                                                                  conv1d_62[0][0]
# __________________________________________________________________________________________________
# conv1d_63 (Conv1D)              (None, 4096, 64)     8256        multiply_20[0][0]
# __________________________________________________________________________________________________
# add_21 (Add)                    (None, 4096, 64)     0           conv1d_3[0][0]
#                                                                  conv1d_6[0][0]
#                                                                  conv1d_9[0][0]
#                                                                  conv1d_12[0][0]
#                                                                  conv1d_15[0][0]
#                                                                  conv1d_18[0][0]
#                                                                  conv1d_21[0][0]
#                                                                  conv1d_24[0][0]
#                                                                  conv1d_27[0][0]
#                                                                  conv1d_30[0][0]
#                                                                  conv1d_33[0][0]
#                                                                  conv1d_36[0][0]
#                                                                  conv1d_39[0][0]
#                                                                  conv1d_42[0][0]
#                                                                  conv1d_45[0][0]
#                                                                  conv1d_48[0][0]
#                                                                  conv1d_51[0][0]
#                                                                  conv1d_54[0][0]
#                                                                  conv1d_57[0][0]
#                                                                  conv1d_60[0][0]
#                                                                  conv1d_63[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 4096, 64)     0           add_21[0][0]
# __________________________________________________________________________________________________
# conv1d_64 (Conv1D)              (None, 4096, 64)     4160        activation[0][0]
# __________________________________________________________________________________________________
# conv1d_65 (Conv1D)              (None, 128, 64)      131136      conv1d_64[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 128, 64)      0           conv1d_65[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128, 5)       325         dropout[0][0]
# ==================================================================================================
# Total params: 1,350,213
# Trainable params: 1,350,213
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Shapes of `(batch_X, batch_y)`: (16, 4096, 8), (16, 128, 5)
# Epoch 1/15

# %%
# What's up with this well -- all sand?
from coremdlr.viz import CorePlotter

fdset = Facies

well = fdset.get_well("204-20-1Z")

cplotter = CorePlotter(figsize=(10,200))
cplotter.plot_image(well._image / 255.0, depths=well._depth)

labels = well.make_striplog()
cplotter.plot_strip(labels)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-7f0bbd461dc4> in <module>()
#       2 from coremdlr.viz import CorePlotter
#       3
# ----> 4 fdset = Facies
#       5
#       6 well = fdset.get_well("204-20-1Z")
#
# NameError: name 'Facies' is not defined

# %% [markdown]
# ## Categorical Loss

# %%
well_names = ["205-21b-3", "204-20-6a", "204-20-1Z", "204-19-6", "204-24a-6"]

fdset = FaciesDataset(well_names[:-1], [well_names[-1]], features=['pseudoGR'], label_resolution=32)

fdset.load_or_generate_data()

# %%
wavenet_model_args = {
    'feature' : 'pseudoGR',
    'network' : 'wavenet',
    'summary' : False,
    'sequence_size' : 128,
    'network_args' : {
        'num_blocks' : 20,
        'block_filters' : 128,
        'residual_filters' : 64,
        'output_resolution' : fdset.label_resolution,
        'dropout_rate' : 0.5,
    },
    'optimizer_args' : {
        'optimizer' : 'Adam',
    },
    'loss' : 'categorical_crossentropy'
}

fit_args = {
    'batch_size' : 32,
    'epochs' : 15,
    'step_size' : wavenet_model.sequence_size - 32
}

# %%
fit_args = {
    'batch_size' : 32,
    'epochs' : 15,
    'step_size' : wavenet_model.sequence_size - 32
}

wavenet_model.fit(fdset, **fit_args)

# %%
from sklearn.metrics import confusion_matrix

y_pred = wavenet_model.predict(fdset.X_test)

cm = confusion_matrix(fdset.y_test, y_pred)

model_plots.confusion_matrix_plot(cm, fdset.classes)

# %% [markdown]
# ## Ordinal Loss

# %%
wavenet_model_args['loss'] = 'ordinal_squared_error'

wavenet_model = NetworkModel(fdset, model_args=wavenet_model_args)

wavenet_model.fit(fdset, **fit_args)

# %%
y_pred = wavenet_model.predict(fdset.X_test)

cm = confusion_matrix(fdset.y_test, y_pred)

model_plots.confusion_matrix_plot(cm, fdset.classes)

# %% [markdown]
# ## Combined Loss

# %%
wavenet_model_args['loss'] = {'categorical_crossentropy': 0.15, 
                              'ordinal_squared_error' : 0.85}

wavenet_model = NetworkModel(fdset, model_args=wavenet_model_args)

# %%
wavenet_model.fit(fdset, **fit_args)

# %%
y_pred = wavenet_model.predict(fdset.X_test)

cm = confusion_matrix(fdset.y_test, y_pred)

model_plots.confusion_matrix_plot(cm, fdset.classes)

# %% [markdown]
# ## Try same with class weighting

# %%
fit_args['class_weighted'] = True
fit_args['epochs'] = 9

wavenet_model = NetworkModel(fdset, model_args=wavenet_model_args)

wavenet_model.fit(fdset, **fit_args)

# %%
y_pred = wavenet_model.predict(fdset.X_test)

cm = confusion_matrix(fdset.y_test, y_pred)

model_plots.confusion_matrix_plot(cm, fdset.classes)

# %%
np.bincount(fdset.y_train) / fdset.y_train.size

# %%
fit_args['class_weighted'] = True
fit_args['epochs'] = 30

wavenet_model = NetworkModel(fdset, model_args=wavenet_model_args)

wavenet_model.fit(fdset, **fit_args)
