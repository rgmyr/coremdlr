# %% [markdown]
# # Testing XGB on Psuedo Gamma datasets

# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt

from corebreakout.facies.datasets import WellLoader, FaciesDataset
from corebreakout.facies.models import FeaturePredictor, LambdaModel

# %% [markdown]
# ### Compare scaling methods

# %%
fdset = FaciesDataset(["205-21b-3", "204-24a-6", "204-20-6a", "204-19-6"],
                    test_wells=["204-19-6"],
                    features=["pseudoGR"],
                    pseudoGR_args={'scale_mode': None},
                    label_resolution=32)

fdset.load_or_generate_data()
# Out:
# /home/administrator/Dropbox/core_data/facies/train_data 205-21b-3
# /home/administrator/Dropbox/core_data/facies/train_data 204-24a-6
# /home/administrator/Dropbox/core_data/facies/train_data 204-20-6a
# /home/administrator/Dropbox/core_data/facies/train_data 204-19-6
# /home/administrator/Dropbox/core_data/facies/train_data 204-19-6
# Loading Well:  205-21b-3
# Feature shapes:  [('depth', (3841,)), ('pseudoGR', (3841, 32))]
# Loading Well:  204-24a-6
# Feature shapes:  [('depth', (13010,)), ('pseudoGR', (13010, 32))]
# Loading Well:  204-20-6a
# Feature shapes:  [('depth', (3869,)), ('pseudoGR', (3869, 32))]
# Loading Well:  204-19-6
# Feature shapes:  [('depth', (1884,)), ('pseudoGR', (1884, 32))]
# Loading Well:  204-19-6
# Feature shapes:  [('depth', (1884,)), ('pseudoGR', (1884, 32))]

# %%
for scale_mode in [None, 'minmax', 'standard', 'robust', 'power']:
    
    fdset = FaciesDataset(["205-21b-3", "204-20-6a", "204-19-6", "204-24a-6"],
                    test_wells=[],
                    features=["pseudoGR"],
                    pseudoGR_args={'scale_mode': scale_mode},
                    label_resolution=32)
    
    fdset.load_or_generate_data()
    
    pGR = fdset.X_train['pseudoGR'].flatten()
    min_y, max_y = pGR.min(), pGR.max()
    
    plt.figure(figsize=(20,5))
    plt.title(scale_mode, size=24)
    plt.plot(np.arange(pGR.size), pGR)
    
    for idx in fdset.X_train['boundary_idxs']:
        plt.plot([idx*32, idx*32], [min_y,max_y], color='red')
        
    plt.show()
# Out:
# /home/administrator/Dropbox/core_data/facies/train_data 205-21b-3
# Loading well with dummy labels. DO NOT TRAIN ON THIS WELL!
# /home/administrator/Dropbox/core_data/facies/train_data 204-20-6a
# Loading well with dummy labels. DO NOT TRAIN ON THIS WELL!
# /home/administrator/Dropbox/core_data/facies/train_data 204-19-6
# Loading well with dummy labels. DO NOT TRAIN ON THIS WELL!
# /home/administrator/Dropbox/core_data/facies/train_data 204-24a-6
# Loading well with dummy labels. DO NOT TRAIN ON THIS WELL!
# Loading Well:  205-21b-3
# Feature shapes:  [('depth', (4332,)), ('pseudoGR', (4332, 32))]
# Loading Well:  204-20-6a
# Feature shapes:  [('depth', (4127,)), ('pseudoGR', (4127, 32))]
# Loading Well:  204-19-6
# Feature shapes:  [('depth', (2078,)), ('pseudoGR', (2078, 32))]
# Loading Well:  204-24a-6
# Feature shapes:  [('depth', (13636,)), ('pseudoGR', (13636, 32))]
# /home/administrator/Dropbox/core_data/facies/train_data 205-21b-3
# Loading well with dummy labels. DO NOT TRAIN ON THIS WELL!
# /home/administrator/Dropbox/core_data/facies/train_data 204-20-6a
# Loading well with dummy labels. DO NOT TRAIN ON THIS WELL!
# /home/administrator/Dropbox/core_data/facies/train_data 204-19-6
# Loading well with dummy labels. DO NOT TRAIN ON THIS WELL!
# /home/administrator/Dropbox/core_data/facies/train_data 204-24a-6
# Loading well with dummy labels. DO NOT TRAIN ON THIS WELL!
# Loading Well:  205-21b-3
# Feature shapes:  [('depth', (4325,)), ('pseudoGR', (4325, 32))]
# Loading Well:  204-20-6a
# Feature shapes:  [('depth', (4126,)), ('pseudoGR', (4126, 32))]
# Loading Well:  204-19-6
# Feature shapes:  [('depth', (2075,)), ('pseudoGR', (2075, 32))]
# Loading Well:  204-24a-6
# Feature shapes:  [('depth', (13638,)), ('pseudoGR', (13638, 32))]
# /home/administrator/Dropbox/core_data/facies/train_data 205-21b-3
# Loading well with dummy labels. DO NOT TRAIN ON THIS WELL!
# /home/administrator/Dropbox/core_data/facies/train_data 204-20-6a
# Loading well with dummy labels. DO NOT TRAIN ON THIS WELL!
# /home/administrator/Dropbox/core_data/facies/train_data 204-19-6
# Loading well with dummy labels. DO NOT TRAIN ON THIS WELL!
# /home/administrator/Dropbox/core_data/facies/train_data 204-24a-6
# Loading well with dummy labels. DO NOT TRAIN ON THIS WELL!
# Loading Well:  205-21b-3
# Feature shapes:  [('depth', (4329,)), ('pseudoGR', (4329, 32))]
# Loading Well:  204-20-6a
# Feature shapes:  [('depth', (4130,)), ('pseudoGR', (4130, 32))]
# Loading Well:  204-19-6
# Feature shapes:  [('depth', (2072,)), ('pseudoGR', (2072, 32))]
# Loading Well:  204-24a-6
# Feature shapes:  [('depth', (13642,)), ('pseudoGR', (13642, 32))]
# /home/administrator/Dropbox/core_data/facies/train_data 205-21b-3
# Loading well with dummy labels. DO NOT TRAIN ON THIS WELL!
# /home/administrator/Dropbox/core_data/facies/train_data 204-20-6a
# Loading well with dummy labels. DO NOT TRAIN ON THIS WELL!
# /home/administrator/Dropbox/core_data/facies/train_data 204-19-6
# Loading well with dummy labels. DO NOT TRAIN ON THIS WELL!
# /home/administrator/Dropbox/core_data/facies/train_data 204-24a-6
# Loading well with dummy labels. DO NOT TRAIN ON THIS WELL!
# Loading Well:  205-21b-3
# Feature shapes:  [('depth', (4324,)), ('pseudoGR', (4324, 32))]
# Loading Well:  204-20-6a
# Feature shapes:  [('depth', (4128,)), ('pseudoGR', (4128, 32))]
# Loading Well:  204-19-6
# Feature shapes:  [('depth', (2075,)), ('pseudoGR', (2075, 32))]
# Loading Well:  204-24a-6
# Feature shapes:  [('depth', (13639,)), ('pseudoGR', (13639, 32))]
# /home/administrator/Dropbox/core_data/facies/train_data 205-21b-3
# Loading well with dummy labels. DO NOT TRAIN ON THIS WELL!
# /home/administrator/Dropbox/core_data/facies/train_data 204-20-6a
# Loading well with dummy labels. DO NOT TRAIN ON THIS WELL!
# /home/administrator/Dropbox/core_data/facies/train_data 204-19-6
# Loading well with dummy labels. DO NOT TRAIN ON THIS WELL!
# /home/administrator/Dropbox/core_data/facies/train_data 204-24a-6
# Loading well with dummy labels. DO NOT TRAIN ON THIS WELL!
# Loading Well:  205-21b-3
# Feature shapes:  [('depth', (4329,)), ('pseudoGR', (4329, 32))]
# Loading Well:  204-20-6a
# Feature shapes:  [('depth', (4126,)), ('pseudoGR', (4126, 32))]
# Loading Well:  204-19-6
# Feature shapes:  [('depth', (2077,)), ('pseudoGR', (2077, 32))]
# Loading Well:  204-24a-6
# Feature shapes:  [('depth', (13636,)), ('pseudoGR', (13636, 32))]

# %%
import sys
import warnings

if not sys.warnoptions:
    warnings.simplefilter("ignore")

# %%
import hyperopt
from hyperopt import hp
from hyperopt.pyll.base import scope
from sklearn.metrics import f1_score, log_loss
from sklearn.utils.class_weight import compute_sample_weight

from scipy.stats import mstats


# for balanced log_loss computation
sample_weights = compute_sample_weight('balanced', fdset.y_test) 

# feat_names = ['mean', 'median', 'hmean', 'gmean', 'var', 'IF_0', 'IF_1', 'Chi2', 'p-val']
feat_names = ['mean', 'median', 'gmean', 'var', 'IF_0', 'IF_1', 'm3', 'm2', 'm1', 'b']

def polyfit_coeffs(x):
    p = np.ma.polyfit(np.arange(x.shape[1]), x.T, 3)
    return p.T


def reduce_function(x):
    feats = []
    x = np.ma.masked_invalid(x)
    feats.append(np.mean(x, axis=-1))
    feats.append(np.median(x, axis=-1))
    #feats.append(mstats.hmean(x-x.min(), axis=-1))
    feats.append(mstats.gmean(x, axis=-1))
    feats.append(np.var(x, axis=-1))
    
    # feats.append(sp.signal.qspline1d(x))
    ideal_fourths = mstats.idealfourths(x, axis=-1)
    feats.append(ideal_fourths[:, 0])
    feats.append(ideal_fourths[:, 1])
    
    coeffs = polyfit_coeffs(x)
    for i in range(4):
        feats.append(coeffs[:,i])
    
    #normal_test = mstats.normaltest(x, axis=1)
    #feats.append(normal_test[0])
    #feats.append(normal_test[1])
    # kur_test = mstats.kurtosistest(x, axis =-1)
    # feats.append(kurtosistest[:, 0])
    # feats.append(kurtosistest[:, 1])
    
    x_feats = np.array(feats).T
    return x_feats


feat_model_args = {
    # NOTE: key needs to be feature name AND feature must be specified in model_args
    'pseudoGR': {
        'model' : 'LambdaModel',
        'model_args' : {
            'feature' : 'pseudoGR',
            'lambda_fn' : reduce_function
        }
    }
}

XGB_SEARCH_SPACE = {
    'model_type' : 'XGB',
    'max_depth' : scope.int(hp.quniform('max_depth', 3, 10, 1)),
    'learning_rate' : hp.uniform('learning_rate', 0.01, 0.2),
    'n_estimators' : scope.int(hp.quniform('n_estimators', 10, 1000, 1)),
    'objective' : 'multi:softprob',
    'n_jobs' : 2,
    'gamma' : hp.uniform('gamma', 0, 0.5),
    'subsample' : hp.uniform('subsample', 0.3, 1),
    'colsample_bytree' : hp.uniform('colsample_bytree', 0.3, 1.0),
    'colsample_bylevel' : 1,
    'reg_alpha' : 0,                                    # L1 penalty
    'reg_lambda' : hp.uniform('reg_lambda', 0.1, 10),   # L2 penalty
    'tree_method' : 'gpu_exact',
}

def train_xgb_model(model_config):
    xgb_predictor = FeaturePredictor(fdset, 
                                     model_args=model_config, 
                                     feature_model_args=feat_model_args)
    test_acc = xgb_predictor.fit(fdset, verbose=False)
    y_pred = xgb_predictor.predict(fdset.X_test)
    print('F1 score:', f1_score(fdset.y_test, y_pred, average='macro'))
    return log_loss(fdset.y_test, xgb_predictor.predict_proba(fdset.X_test)) #, sample_weight=sample_weights)

# %%
best_params = hyperopt.fmin(
    fn=train_xgb_model,
    space=XGB_SEARCH_SPACE,
    algo=hyperopt.rand.suggest,
    max_evals=10
)
# Out:
# Training model for feature:  pseudoGR
# F1 score: 0.26234165553896904
# Training model for feature:  pseudoGR
# F1 score: 0.2644291779259747
# Training model for feature:  pseudoGR
# F1 score: 0.27932612901036247
# Training model for feature:  pseudoGR
# F1 score: 0.2793460986391738
# Training model for feature:  pseudoGR
# F1 score: 0.2669928414070584
# Training model for feature:  pseudoGR
# F1 score: 0.27296315824270934
# Training model for feature:  pseudoGR
# F1 score: 0.2656160157665248
# Training model for feature:  pseudoGR
# F1 score: 0.28204789186909957
# Training model for feature:  pseudoGR
# F1 score: 0.27070690481924625
# Training model for feature:  pseudoGR
# F1 score: 0.2673508579345715

# %%
best_params
# Out:
# {'colsample_bytree': 0.6732219523142804,
#  'gamma': 0.37873561806131767,
#  'learning_rate': 0.01645457552645247,
#  'max_depth': 5.0,
#  'n_estimators': 428.0,
#  'reg_lambda': 7.2393369856630905,
#  'subsample': 0.5044087087681078}

# %%
params = {**XGB_SEARCH_SPACE, 
          **best_params, 
          **{'max_depth': int(best_params['max_depth']), 'n_estimators': int(best_params['n_estimators'])}}

xgb_predictor = FeaturePredictor(fdset, model_args=params, feature_model_args=feat_model_args)
xgb_predictor.fit(fdset, verbose=True)

imps = list(zip(feat_names, xgb_predictor.model.feature_importances_))
imps.sort(key = lambda p: p[1])
[print(pair) for pair in imps[::-1]]
# Out:
# Training model for feature:  pseudoGR
#                       precision    recall  f1-score   support
#
#            sandstone       0.33      0.26      0.29       385
# clay-prone sandstone       0.14      0.12      0.12       226
#       sandy mudstone       0.35      0.21      0.26       477
#             mudstone       0.35      0.65      0.45       350
#
#            micro avg       0.32      0.32      0.32      1438
#            macro avg       0.29      0.31      0.28      1438
#         weighted avg       0.31      0.32      0.29      1438
#
# Total accuracy Score :  0.3150208623087622
# Confusion Matrix:
#  [[101 106  83  95]
#  [ 81  26  53  66]
#  [ 75  36  99 267]
#  [ 50  23  50 227]]
# ('var', 0.178331)
# ('b', 0.13411641)
# ('IF_1', 0.11556802)
# ('median', 0.10157784)
# ('m3', 0.09379383)
# ('gmean', 0.08748247)
# ('m1', 0.084081344)
# ('IF_0', 0.07745442)
# ('mean', 0.06875876)
# ('m2', 0.058835905)
# [None, None, None, None, None, None, None, None, None, None]

# %% [markdown]
# ## Try Power Scaling

# %%
del fdset

fdset2 = FaciesDataset(["205-21b-3", "204-24a-6", "204-20-6a"],
                    test_wells=["204-19-6"],
                    features=["pseudoGR"],
                    pseudoGR_args={'scale_mode': 'power'},
                    label_resolution=32*4)

fdset2.load_or_generate_data()
# Out:
# /home/administrator/Dropbox/core_data/facies/train_data 205-21b-3
# /home/administrator/Dropbox/core_data/facies/train_data 204-24a-6
# /home/administrator/Dropbox/core_data/facies/train_data 204-20-6a
# /home/administrator/Dropbox/core_data/facies/train_data 204-19-6
# Loading Well:  205-21b-3
# Feature shapes:  [('depth', (958,)), ('pseudoGR', (958, 128))]
# Loading Well:  204-24a-6
# Feature shapes:  [('depth', (3254,)), ('pseudoGR', (3254, 128))]
# Loading Well:  204-20-6a
# Feature shapes:  [('depth', (966,)), ('pseudoGR', (966, 128))]
# Loading Well:  204-19-6
# Feature shapes:  [('depth', (473,)), ('pseudoGR', (473, 128))]

# %%
def train_xgb_model2(model_config):
    xgb_predictor = FeaturePredictor(fdset2, 
                                     model_args=model_config, 
                                     feature_model_args=feat_model_args)
    test_acc = xgb_predictor.fit(fdset2, verbose=False)
    y_pred = xgb_predictor.predict(fdset2.X_test)
    print('F1 score:', f1_score(fdset2.y_test, y_pred, average='macro'))
    return log_loss(fdset2.y_test, xgb_predictor.predict_proba(fdset2.X_test))

# %%
best_params = hyperopt.fmin(
    fn=train_xgb_model2,
    space=XGB_SEARCH_SPACE,
    algo=hyperopt.rand.suggest,
    max_evals=10
)
# Out:
# Training model for feature:  pseudoGR
# F1 score: 0.316293598758073
# Training model for feature:  pseudoGR
# F1 score: 0.3108731133705788
# Training model for feature:  pseudoGR
# F1 score: 0.3282579399948633
# Training model for feature:  pseudoGR
# F1 score: 0.3078283653362823
# Training model for feature:  pseudoGR
# F1 score: 0.34565644416323393
# Training model for feature:  pseudoGR
# F1 score: 0.31698218477335544
# Training model for feature:  pseudoGR
# F1 score: 0.2982018839642158
# Training model for feature:  pseudoGR
# F1 score: 0.3198552050130397
# Training model for feature:  pseudoGR
# F1 score: 0.3387865466889208
# Training model for feature:  pseudoGR
# F1 score: 0.2804058698020451

# %%
params = {**XGB_SEARCH_SPACE, 
          **best_params, 
          **{'max_depth': int(best_params['max_depth']), 'n_estimators': int(best_params['n_estimators'])}}

xgb_predictor = FeaturePredictor(fdset2, model_args=params, feature_model_args=feat_model_args)
xgb_predictor.fit(fdset2, verbose=True)

imps = list(zip(feat_names, xgb_predictor.model.feature_importances_))
imps.sort(key = lambda p: p[1])
[print(pair) for pair in imps[::-1]]
# Out:
# Training model for feature:  pseudoGR
#                       precision    recall  f1-score   support
#
#            sandstone       0.84      0.44      0.58       234
# clay-prone sandstone       0.00      0.00      0.00        79
#       sandy mudstone       0.17      0.40      0.24        72
#             mudstone       0.43      0.84      0.56        88
#
#            micro avg       0.44      0.44      0.44       473
#            macro avg       0.36      0.42      0.35       473
#         weighted avg       0.52      0.44      0.43       473
#
# Total accuracy Score :  0.4376321353065539
# Confusion Matrix:
#  [[104   0  86  44]
#  [ 17   0  48  14]
#  [  1   0  29  42]
#  [  2   2  10  74]]
# ('var', 0.23149236)
# ('IF_1', 0.17626321)
# ('b', 0.10144927)
# ('median', 0.08382295)
# ('IF_0', 0.08343126)
# ('m3', 0.079905994)
# ('m1', 0.07716412)
# ('gmean', 0.07363886)
# ('mean', 0.05757932)
# ('m2', 0.035252646)
# [None, None, None, None, None, None, None, None, None, None]
