# %%
import lasio
import pandas as pd
import numpy as np

# %%
logs_file = '/home/administrator/Dropbox/core_data/facies/train_data/204-19-6_logs.las'
logs_df = lasio.read(logs_file).df()
# Out:
# Header section Parameter regexp=~P was not found.

# %%
logs_df.columns
# Out:
# Index(['CALI', 'DENC', 'DENS', 'DTC', 'DTS1', 'DTS2', 'GR', 'NEUT', 'PEF',
#        'RDEP', 'RMIC', 'RSHAL', 'SP'],
#       dtype='object')

# %%
logs_df.isna().count(), logs_df.index.size
# Out:
# (CALI     15092
#  DENC     15092
#  DENS     15092
#  DTC      15092
#  DTS1     15092
#  DTS2     15092
#  GR       15092
#  NEUT     15092
#  PEF      15092
#  RDEP     15092
#  RMIC     15092
#  RSHAL    15092
#  SP       15092
#  dtype: int64, 15092)

# %%
logs_file = '/home/administrator/Dropbox/core_data/facies/train_data/204-20-6a_logs.las'
logs_df = lasio.read(logs_file).df()
logs_df.columns
# Out:
# Header section Parameter regexp=~P was not found.
# Index(['AT60', 'CALI', 'DENC', 'DENS', 'DTC', 'DTS', 'GR', 'NEUT', 'PEF',
#        'RDEP', 'RMED', 'RSHAL'],
#       dtype='object')

# %%
logs_df.isna().count(), logs_df.index.size
# Out:
# (AT60     14751
#  CALI     14751
#  DENC     14751
#  DENS     14751
#  DTC      14751
#  DTS      14751
#  GR       14751
#  NEUT     14751
#  PEF      14751
#  RDEP     14751
#  RMED     14751
#  RSHAL    14751
#  dtype: int64, 14751)

# %%
lf = lasio.read(logs_file)
# Out:
# Header section Parameter regexp=~P was not found.

# %%
dir(lf)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_text',
#  'add_curve',
#  'add_curve_raw',
#  'append_curve',
#  'append_curve_item',
#  'curves',
#  'curvesdict',
#  'data',
#  'delete_curve',
#  'depth_ft',
#  'depth_m',
#  'df',
#  'encoding',
#  'get_curve',
#  'header',
#  'index',
#  'index_unit',
#  'insert_curve',
#  'insert_curve_item',
#  'items',
#  'iteritems',
#  'iterkeys',
#  'itervalues',
#  'json',
#  'keys',
#  'match_raw_section',
#  'metadata',
#  'other',
#  'params',
#  'raw_sections',
#  'read',
#  'sections',
#  'set_data',
#  'set_data_from_df',
# ...

# %%
lf.values()
# Out:
# [array([ 457.    ,  457.1524,  457.3048, ..., 2704.5952, 2704.7476,
#         2704.9   ]),
#  array([nan, nan, nan, ..., nan, nan, nan]),
#  array([nan, nan, nan, ..., nan, nan, nan]),
#  array([nan, nan, nan, ..., nan, nan, nan]),
#  array([nan, nan, nan, ..., nan, nan, nan]),
#  array([nan, nan, nan, ..., nan, nan, nan]),
#  array([nan, nan, nan, ..., nan, nan, nan]),
#  array([nan, nan, nan, ..., nan, nan, nan]),
#  array([nan, nan, nan, ..., nan, nan, nan]),
#  array([nan, nan, nan, ..., nan, nan, nan]),
#  array([nan, nan, nan, ..., nan, nan, nan]),
#  array([nan, nan, nan, ..., nan, nan, nan]),
#  array([nan, nan, nan, ..., nan, nan, nan])]

# %%
logs_df = lf.df()

# %%
cond = (2175 <= logs_df.index)
cond2 = (logs_df.index <= 2200)
logs_df[cond & cond2]
# Out:
#               AT60     CALI    DENC    DENS       DTC       DTS       GR  \
# DEPTH
# 2175.0052  44.6350  12.7316  0.0026  2.1735   98.2955  195.1262  34.4035
# 2175.1576  37.7605  12.6997 -0.0127  2.1739   97.6885  188.3434  30.3090
# 2175.3100  36.9033  12.7701 -0.0111  2.1990   96.3291  192.2567  31.3312
# 2175.4624  53.8636  12.6457 -0.0117  2.2104   95.7009  189.5175  30.5660
# 2175.6148  35.2632  12.5915 -0.0146  2.2216   95.5966  189.0858  31.3243
# 2175.7672  22.6363  12.4770 -0.0141  2.2315   95.5400  180.8995  32.4482
# 2175.9196  13.9423  12.4151 -0.0116  2.2577   94.3143  180.2883  36.0550
# 2176.0720  11.3222  12.4114 -0.0146  2.2954   96.1936  176.1380  38.4423
# 2176.2244   5.8073  12.4059 -0.0130  2.3486   96.7802  177.9785  47.8227
# 2176.3768   4.5817  12.4574 -0.0124  2.3571   97.4163  188.6359  48.3556
# 2176.5292   3.9982  12.3645 -0.0125  2.3347   99.4411  188.0279  47.2943
# 2176.6816   3.7840  12.1782 -0.0140  2.3359  100.5260  194.2289  52.9932
# ...

# %%
logs_df["TEST_NAN"] = np.nan
logs_df
# Out:
#            AT60  CALI  DENC  DENS  DTC  DTS       GR  NEUT  PEF  RDEP  RMED  \
# DEPTH
# 457.0000    NaN   NaN   NaN   NaN  NaN  NaN      NaN   NaN  NaN   NaN   NaN
# 457.1524    NaN   NaN   NaN   NaN  NaN  NaN      NaN   NaN  NaN   NaN   NaN
# 457.3048    NaN   NaN   NaN   NaN  NaN  NaN      NaN   NaN  NaN   NaN   NaN
# 457.4572    NaN   NaN   NaN   NaN  NaN  NaN  10.8312   NaN  NaN   NaN   NaN
# 457.6096    NaN   NaN   NaN   NaN  NaN  NaN   9.4180   NaN  NaN   NaN   NaN
# 457.7620    NaN   NaN   NaN   NaN  NaN  NaN   9.0442   NaN  NaN   NaN   NaN
# 457.9144    NaN   NaN   NaN   NaN  NaN  NaN  10.4243   NaN  NaN   NaN   NaN
# 458.0668    NaN   NaN   NaN   NaN  NaN  NaN   9.6658   NaN  NaN   NaN   NaN
# 458.2192    NaN   NaN   NaN   NaN  NaN  NaN  10.1648   NaN  NaN   NaN   NaN
# 458.3716    NaN   NaN   NaN   NaN  NaN  NaN  10.1072   NaN  NaN   NaN   NaN
# 458.5240    NaN   NaN   NaN   NaN  NaN  NaN   9.4851   NaN  NaN   NaN   NaN
# ...

# %%
logs_df
# Out:
#            AT60  CALI  DENC  DENS  DTC  DTS       GR  NEUT  PEF  RDEP  RMED  \
# DEPTH
# 457.0000    NaN   NaN   NaN   NaN  NaN  NaN      NaN   NaN  NaN   NaN   NaN
# 457.1524    NaN   NaN   NaN   NaN  NaN  NaN      NaN   NaN  NaN   NaN   NaN
# 457.3048    NaN   NaN   NaN   NaN  NaN  NaN      NaN   NaN  NaN   NaN   NaN
# 457.4572    NaN   NaN   NaN   NaN  NaN  NaN  10.8312   NaN  NaN   NaN   NaN
# 457.6096    NaN   NaN   NaN   NaN  NaN  NaN   9.4180   NaN  NaN   NaN   NaN
# 457.7620    NaN   NaN   NaN   NaN  NaN  NaN   9.0442   NaN  NaN   NaN   NaN
# 457.9144    NaN   NaN   NaN   NaN  NaN  NaN  10.4243   NaN  NaN   NaN   NaN
# 458.0668    NaN   NaN   NaN   NaN  NaN  NaN   9.6658   NaN  NaN   NaN   NaN
# 458.2192    NaN   NaN   NaN   NaN  NaN  NaN  10.1648   NaN  NaN   NaN   NaN
# 458.3716    NaN   NaN   NaN   NaN  NaN  NaN  10.1072   NaN  NaN   NaN   NaN
# 458.5240    NaN   NaN   NaN   NaN  NaN  NaN   9.4851   NaN  NaN   NaN   NaN
# ...

# %%
# Out:
# array([ True,  True,  True, ...,  True,  True,  True])
