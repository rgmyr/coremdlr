# %%
import numpy as np
import scipy as sp
from corebreakout.facies.datasets import WellLoader, FaciesDataset
from corebreakout.facies.models import FeaturePredictor, LambdaModel
# Out:
# Using TensorFlow backend.

# %%
# probably not good to get into the habit of ignorning all of the RuntimeWarnings
# but it keeps things cleaner for now

import sys
import warnings

if not sys.warnoptions:
    warnings.simplefilter("ignore")

# %%
fdset = FaciesDataset(["205-21b-3", "204-24a-6", "204-20-6a"],
                    test_wells=["204-19-6"],
                    features=["pseudoGR", "logs"],
                    label_resolution=32)

fdset.load_or_generate_data()
# Out:
# /home/administrator/Dropbox/core_data/facies/train_data 205-21b-3
# /home/administrator/Dropbox/core_data/facies/train_data 204-24a-6
# /home/administrator/Dropbox/core_data/facies/train_data 204-20-6a
# /home/administrator/Dropbox/core_data/facies/train_data 204-19-6
# Loading Well:  205-21b-3
# Header section Parameter regexp=~P was not found.
# Adding NaN log:  SP
# Adding NaN log:  DTS
# Feature shapes:  [('depth', (3841,)), ('pseudoGR', (3841, 32)), ('logs', (3841, 11))]
# Loading Well:  204-24a-6
# Header section Parameter regexp=~P was not found.
# Adding NaN log:  SP
# Adding NaN log:  DTS1
# Adding NaN log:  DTS2
# Feature shapes:  [('depth', (13000,)), ('pseudoGR', (13000, 32)), ('logs', (13000, 11))]
# Loading Well:  204-20-6a
# Header section Parameter regexp=~P was not found.
# Adding NaN log:  SP
# Adding NaN log:  DTS1
# Adding NaN log:  DTS2
# Feature shapes:  [('depth', (3873,)), ('pseudoGR', (3873, 32)), ('logs', (3873, 11))]
# Loading Well:  204-19-6
# Header section Parameter regexp=~P was not found.
# Adding NaN log:  DTS
# Feature shapes:  [('depth', (1884,)), ('pseudoGR', (1884, 32)), ('logs', (1884, 11))]

# %%
import hyperopt
from hyperopt import hp
from hyperopt.pyll.base import scope

from sklearn.metrics import f1_score, log_loss
from sklearn.utils.class_weight import compute_sample_weight

from scipy.stats import mstats


# for balanced training and log_loss computation
train_sample_weights = compute_sample_weight('balanced', fdset.y_train)
test_sample_weights = compute_sample_weight('balanced', fdset.y_test)

# feat_names = ['mean', 'median', 'hmean', 'gmean', 'var', 'IF_0', 'IF_1', 'Chi2', 'p-val']
feat_names = ['mean', 'median', 'hmean', 'gmean', 'var', 'IF_0', 'IF_1']

def reduce_function(x):
    
    feats = []
    x = np.ma.masked_invalid(x)
    x = np.ma.masked_less_equal(x, 0.1)
    
    # central tendency
    feats.append(np.mean(x, axis=-1))
    feats.append(np.median(x, axis=-1))
    feats.append(mstats.hmean(x, axis=-1))
    feats.append(mstats.gmean(x, axis=-1))
    
    # dispersion
    feats.append(np.var(x, axis=-1))
    ideal_fourths = mstats.idealfourths(x, axis=-1)
    feats.append(ideal_fourths[:, 0])
    feats.append(ideal_fourths[:, 1])
    
    # TODO: curvature

    x_feats = np.array(feats).T
    
    return x_feats


feat_model_args = {
    # NOTE: key needs to be feature name AND feature must be specified in model_args
    'pseudoGR': {
        'model' : 'LambdaModel',
        'model_args' : {
            'feature' : 'pseudoGR',
            'lambda_fn' : reduce_function
        }
    }
}

XGB_SEARCH_SPACE = {
    'model_type' : 'XGB',
    'max_depth' : scope.int(hp.quniform('max_depth', 3, 10, 1)),
    'learning_rate' : hp.uniform('learning_rate', 0.01, 0.2),
    'n_estimators' : scope.int(hp.quniform('n_estimators', 10, 1000, 1)),
    'objective' : 'multi:softprob',
    'n_jobs' : 2,
    'gamma' : hp.uniform('gamma', 0, 0.5),
    'subsample' : hp.uniform('subsample', 0.3, 1),
    'colsample_bytree' : hp.uniform('colsample_bytree', 0.3, 1.0),
    'colsample_bylevel' : 1,
    'reg_alpha' : 0,                                    # L1 penalty
    'reg_lambda' : hp.uniform('reg_lambda', 0.1, 10),   # L2 penalty
    'tree_method' : 'gpu_exact',
}

def train_xgb_model(model_config):
    xgb_predictor = FeaturePredictor(fdset, 
                                     model_args=model_config, 
                                     feature_model_args=feat_model_args)
    test_acc = xgb_predictor.fit(fdset, verbose=False, sample_weight=train_sample_weights)
    y_pred = xgb_predictor.predict(fdset.X_test)
    print('F1 score:', f1_score(fdset.y_test, y_pred, average='macro'))
    return log_loss(fdset.y_test, xgb_predictor.predict_proba(fdset.X_test), sample_weight=test_sample_weights)

# %%
best_params = hyperopt.fmin(
    fn=train_xgb_model,
    space=XGB_SEARCH_SPACE,
    algo=hyperopt.rand.suggest,
    max_evals=50
)
# Out:
# Training model for feature:  pseudoGR
# F1 score: 0.4004978241722509
# Training model for feature:  pseudoGR
# F1 score: 0.410320930567297
# Training model for feature:  pseudoGR
# F1 score: 0.4124392305011455
# Training model for feature:  pseudoGR
# F1 score: 0.4146377434336295
# Training model for feature:  pseudoGR
# F1 score: 0.41214222190146654
# Training model for feature:  pseudoGR
# F1 score: 0.38846950417394455
# Training model for feature:  pseudoGR
# F1 score: 0.3923787825400469
# Training model for feature:  pseudoGR
# F1 score: 0.410613614489874
# Training model for feature:  pseudoGR
# F1 score: 0.3883720528542204
# Training model for feature:  pseudoGR
# F1 score: 0.3985378301946619
# Training model for feature:  pseudoGR
# F1 score: 0.4074865056123448
# Training model for feature:  pseudoGR
# F1 score: 0.4182740208469155
# Training model for feature:  pseudoGR
# F1 score: 0.3945277321270749
# Training model for feature:  pseudoGR
# F1 score: 0.39796981249184515
# Training model for feature:  pseudoGR
# F1 score: 0.40565917213791824
# Training model for feature:  pseudoGR
# F1 score: 0.4051420105213067
# Training model for feature:  pseudoGR
# F1 score: 0.3893723110017132
# Training model for feature:  pseudoGR
# F1 score: 0.4055568195645164
# Training model for feature:  pseudoGR
# F1 score: 0.4112129002776378
# Training model for feature:  pseudoGR
# F1 score: 0.40445853835257617
# Training model for feature:  pseudoGR
# F1 score: 0.4111104225123271
# Training model for feature:  pseudoGR
# F1 score: 0.4075855628595819
# Training model for feature:  pseudoGR
# F1 score: 0.3983524665615361
# Training model for feature:  pseudoGR
# F1 score: 0.40121691569262413
# Training model for feature:  pseudoGR
# F1 score: 0.40281263879569135
# Training model for feature:  pseudoGR
# F1 score: 0.39078561120017496
# Training model for feature:  pseudoGR
# F1 score: 0.40305904496312506
# Training model for feature:  pseudoGR
# F1 score: 0.40974330400145176
# Training model for feature:  pseudoGR
# F1 score: 0.39558744223508835
# Training model for feature:  pseudoGR
# F1 score: 0.39352839603826
# Training model for feature:  pseudoGR
# F1 score: 0.40535923178065275
# Training model for feature:  pseudoGR
# F1 score: 0.4016681996051417
# Training model for feature:  pseudoGR
# F1 score: 0.4035500280373022
# Training model for feature:  pseudoGR
# F1 score: 0.3943864937176047
# Training model for feature:  pseudoGR
# F1 score: 0.411772263076319
# Training model for feature:  pseudoGR
# F1 score: 0.40778241554051015
# Training model for feature:  pseudoGR
# F1 score: 0.40501889545184044
# Training model for feature:  pseudoGR
# F1 score: 0.4109108421111168
# Training model for feature:  pseudoGR
# F1 score: 0.40300164954132467
# Training model for feature:  pseudoGR
# F1 score: 0.4009464550099312
# Training model for feature:  pseudoGR
# F1 score: 0.4063821613778266
# Training model for feature:  pseudoGR
# F1 score: 0.40888142403716654
# Training model for feature:  pseudoGR
# F1 score: 0.406075859722057
# Training model for feature:  pseudoGR
# F1 score: 0.3990620203485242
# Training model for feature:  pseudoGR
# F1 score: 0.3940033151683706
# Training model for feature:  pseudoGR
# F1 score: 0.40429997470944296
# Training model for feature:  pseudoGR
# F1 score: 0.40089699179711336
# Training model for feature:  pseudoGR
# F1 score: 0.40159234110381237
# Training model for feature:  pseudoGR
# F1 score: 0.4074398536903979
# Training model for feature:  pseudoGR
# F1 score: 0.4136481842146744

# %%
best_params
# Out:
# {'colsample_bytree': 0.37535692046957825,
#  'gamma': 0.012272484156789554,
#  'learning_rate': 0.15423275978923737,
#  'max_depth': 3.0,
#  'n_estimators': 53.0,
#  'reg_lambda': 5.7744883399503735,
#  'subsample': 0.9412926204405692}

# %%
params = {**XGB_SEARCH_SPACE, 
          **best_params, 
          **{'max_depth': int(best_params['max_depth']), 'n_estimators': int(best_params['n_estimators'])}}
                              
xgb_predictor = FeaturePredictor(fdset, model_args=params, feature_model_args=feat_model_args)
xgb_predictor.fit(fdset, verbose=True)

imps = list(zip(feat_names, xgb_predictor.model.feature_importances_))
imps.sort(key = lambda p: p[1])
print()
[print(pair) for pair in imps[::-1]]
# Out:
# Training model for feature:  pseudoGR
# /home/administrator/anaconda3/envs/core-dev/lib/python3.6/site-packages/numpy/core/fromnumeric.py:688: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   a.partition(kth, axis=axis, kind=kind, order=order)
#                       precision    recall  f1-score   support
#
#            sandstone       0.68      0.80      0.74       934
# clay-prone sandstone       0.05      0.01      0.01       307
#       sandy mudstone       0.33      0.41      0.37       285
#             mudstone       0.53      0.59      0.56       358
#
#          avg / total       0.50      0.57      0.53      1884
#
# Total accuracy Score :  0.5727176220806794
# Confusion Matrix:
#  [[748   3 108  75]
#  [242   2  36  27]
#  [ 75   9 116  85]
#  [ 30  25  90 213]]
#
# ('var', 0.37428978)
# ('IF_1', 0.23011364)
# ('IF_0', 0.1512784)
# ('median', 0.09801137)
# ('hmean', 0.053977273)
# ('mean', 0.052556816)
# ('gmean', 0.039772727)
# /home/administrator/anaconda3/envs/core-dev/lib/python3.6/site-packages/numpy/core/fromnumeric.py:688: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   a.partition(kth, axis=axis, kind=kind, order=order)
# [None, None, None, None, None, None, None]

# %%
df = xgb_predictor.save_preds(fdset.test_well_names[0], None, by_patch=True, include_probas=True)
df
# Out:
#             GR      RDEP         base  confidence   proba_0   proba_1  \
# 0    -1.228834  1.346995  2208.085920    0.462188  0.462188  0.121617
# 1    -1.237774  1.349403  2208.091290    0.391719  0.391719  0.151551
# 2    -1.246714  1.351810  2208.096661    0.478330  0.478330  0.158241
# 3    -1.255544  1.354180  2208.102031    0.402088  0.302543  0.136582
# 4    -1.254832  1.353276  2208.107401    0.424135  0.424135  0.149038
# 5    -1.254119  1.352373  2208.112771    0.406748  0.406748  0.161170
# 6    -1.253407  1.351469  2208.118141    0.370077  0.330457  0.153321
# 1861  0.023504  0.130316  0.571807    0.520593  2220.574593       0       1
# 1862  0.047817  0.111154  0.564846    0.591592  2220.579963       0       1
# 1863  0.116901  0.095501  0.560666    0.724922  2220.585333       0       1
# 1864  0.130657  0.109210  0.551788    0.814352  2220.590703       0       1
# 1865  0.161421  0.108194  0.548491    0.736640  2220.596073       0       1
# 1866  0.161357  0.108915  0.545721    0.722327  2220.601443       0       1
# 1867  0.160972  0.110672  0.539331    0.742929  2220.606813       0       1
# 1868  0.161749  0.106378  0.540096    0.732031  2220.612183       0       1
# 1869  0.155348  0.104123  0.548829    0.746548  2220.617553       0       1
# 1870  0.165720  0.100887  0.549036    0.723685  2220.622923       0       1
# 1871  0.160429  0.090262  0.536985    0.670098  2220.628293       0       1
# 1872  0.156946  0.122712  0.540883    0.811291  2220.633663       0       1
# 1873  0.248952  0.148262  0.500492    1.117923  2220.639033       0       1
# 1874  0.143306  0.121501  0.496367    0.809529  2220.644403       0       1
# 1875  0.143306  0.121501  0.485089    0.809529  2220.649773       0       2
# 1876  0.218194  0.135579  0.480905    0.987177  2220.655143       0       2
# 1877  0.362840  0.149898  0.448477    1.332632  2220.660514       2       2
# 1878  0.443675  0.205155  0.415218    1.657638  2220.665884       2       2
# 1879  0.310201  0.476658  0.386967    2.172866  2220.671254       3       2
# 1880  0.166278  0.706334  0.388026    2.543842  2220.676624       3       2
# 1881  0.360459  0.411020  0.389690    2.090964  2220.681994       3       2
# 1882  0.393975  0.315589  0.405920    1.884619  2220.687364       2       2
# 1883  0.385585  0.150041  0.427232    1.381654  2220.692734       2       2
#
# [1884 rows x 13 columns]

# %%
df.plot(x='top', y='GR', figsize=(15,5))

# %%
df.plot(x='top', y='pseudoGR', figsize=(15,5))

# %%
df.plot(x='top', y='pseudoGR', kind='scatter', figsize=(15,5))

# %% [markdown]
# ## Thoughts
#
# Maybe we should do a little more work on filling in or masking the pseudo gamma. It's computed from the min-max normalized image (hence the 0-1 range), but maybe we should also standardize it after computing (probably less important for XGB model, but may help quite a bit for the networks which currently have comparable performance).

# %%
df['normed_pGR'] = (df.pseudoGR - df.pseudoGR.mean()) / df.pseudoGR.std()
df.plot(x='top', y=['normed_pGR','GR'], figsize=(15,5), ylim=[-2,2])
# Out:
# /home/administrator/anaconda3/envs/core-dev/lib/python3.6/site-packages/pandas/plotting/_core.py:1716: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   series.name = label

# %% [markdown]
# ## Looking at regression estimate / error / confidence

# %%
df['regression_error'] = (df.regression - df.y_true.astype(float)).abs()
sns.scatterplot(x='regression_error', y='confidence', hue='y_true', data=df)

#df.plot(x='regression_error', y='confidence', kind='scatter',  figsize=(15,5))

# %%
import seaborn as sns

df['abs_class_distance'] = (df.y_true - df.y_pred).abs()
sns.violinplot(x='abs_class_distance', y='confidence', data=df)

# %%
df['class_distance'] = (df.y_true - df.y_pred)
sns.violinplot(x='class_distance', y='confidence', data=df)

# %% [markdown]
# ## Confusion Matrices
#
# **NOTE**: probably going to move the analysis visualization functions into a different submodule.

# %%
from sklearn.metrics import confusion_matrix
from corebreakout.facies.models_utils import make_confusion_fig

# %%
classes = fdset.classes
cm = confusion_matrix(df.y_true.values, df.y_pred.values)

# updated function below to have no grid by default
make_confusion_fig(cm, classes)

# %%
make_confusion_fig(cm, classes, normalize=True)
